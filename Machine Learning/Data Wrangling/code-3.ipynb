# %%
import pandas as pd

# %%
df = pd.read_csv("./Documents/datasets/nyc_temperatures.csv")

# %%
df.head()
# Out:
#                   date datatype            station attributes  value
# 0  2018-10-01T00:00:00     TAVG  GHCND:USW00014732      H,,S,   21.2
# 1  2018-10-01T00:00:00     TMAX  GHCND:USW00014732   ,,W,2400   25.6
# 2  2018-10-01T00:00:00     TMIN  GHCND:USW00014732   ,,W,2400   18.3
# 3  2018-10-02T00:00:00     TAVG  GHCND:USW00014732      H,,S,   22.7
# 4  2018-10-02T00:00:00     TMAX  GHCND:USW00014732   ,,W,2400   26.1

# %%
df.columns
# Out:
# Index(['date', 'datatype', 'station', 'attributes', 'value'], dtype='object')

# %%
df.rename(
    columns={
        "value": "temp_C",
        "attributes": "flags"
    }, inplace=True
)

# %%
df.columns
# Out:
# Index(['date', 'datatype', 'station', 'flags', 'temp_C'], dtype='object')

# %%
df.rename(str.upper, axis="columns").columns
# Out:
# Index(['DATE', 'DATATYPE', 'STATION', 'FLAGS', 'TEMP_C'], dtype='object')

# %%
df
# Out:
#                    date datatype            station     flags  temp_C
# 0   2018-10-01T00:00:00     TAVG  GHCND:USW00014732     H,,S,    21.2
# 1   2018-10-01T00:00:00     TMAX  GHCND:USW00014732  ,,W,2400    25.6
# 2   2018-10-01T00:00:00     TMIN  GHCND:USW00014732  ,,W,2400    18.3
# 3   2018-10-02T00:00:00     TAVG  GHCND:USW00014732     H,,S,    22.7
# 4   2018-10-02T00:00:00     TMAX  GHCND:USW00014732  ,,W,2400    26.1
# ..                  ...      ...                ...       ...     ...
# 88  2018-10-30T00:00:00     TMAX  GHCND:USW00014732  ,,W,2400    13.9
# 89  2018-10-30T00:00:00     TMIN  GHCND:USW00014732  ,,W,2400     7.2
# 90  2018-10-31T00:00:00     TAVG  GHCND:USW00014732     H,,S,    12.6
# 91  2018-10-31T00:00:00     TMAX  GHCND:USW00014732  ,,W,2400    17.8
# 92  2018-10-31T00:00:00     TMIN  GHCND:USW00014732  ,,W,2400     7.2
#
# [93 rows x 5 columns]

# %% [markdown]
# # Type Conversion

# %%
df.dtypes
# Out:
# date         object
# datatype     object
# station      object
# flags        object
# temp_C      float64
# dtype: object

# %%
df.loc[:, "date"]
# Out:
# 0     2018-10-01T00:00:00
# 1     2018-10-01T00:00:00
# 2     2018-10-01T00:00:00
# 3     2018-10-02T00:00:00
# 4     2018-10-02T00:00:00
#              ...
# 88    2018-10-30T00:00:00
# 89    2018-10-30T00:00:00
# 90    2018-10-31T00:00:00
# 91    2018-10-31T00:00:00
# 92    2018-10-31T00:00:00
# Name: date, Length: 93, dtype: object

# %%
df.date
# Out:
# 0     2018-10-01T00:00:00
# 1     2018-10-01T00:00:00
# 2     2018-10-01T00:00:00
# 3     2018-10-02T00:00:00
# 4     2018-10-02T00:00:00
#              ...
# 88    2018-10-30T00:00:00
# 89    2018-10-30T00:00:00
# 90    2018-10-31T00:00:00
# 91    2018-10-31T00:00:00
# 92    2018-10-31T00:00:00
# Name: date, Length: 93, dtype: object

# %%
df.columns
# Out:
# Index(['date', 'datatype', 'station', 'flags', 'temp_C'], dtype='object')

# %%
df.date.dtype
# Out:
# dtype('O')

# %%
df = df.reset_index(drop=True)

# %%
df.loc[:, "date"] = pd.to_datetime(df.date)
df.dtypes
# Out:
# date        datetime64[ns]
# datatype            object
# station             object
# flags               object
# temp_C             float64
# dtype: object

# %%
df
# Out:
#          date datatype            station     flags  temp_C
# 0  2018-10-01     TAVG  GHCND:USW00014732     H,,S,    21.2
# 1  2018-10-01     TMAX  GHCND:USW00014732  ,,W,2400    25.6
# 2  2018-10-01     TMIN  GHCND:USW00014732  ,,W,2400    18.3
# 3  2018-10-02     TAVG  GHCND:USW00014732     H,,S,    22.7
# 4  2018-10-02     TMAX  GHCND:USW00014732  ,,W,2400    26.1
# ..        ...      ...                ...       ...     ...
# 88 2018-10-30     TMAX  GHCND:USW00014732  ,,W,2400    13.9
# 89 2018-10-30     TMIN  GHCND:USW00014732  ,,W,2400     7.2
# 90 2018-10-31     TAVG  GHCND:USW00014732     H,,S,    12.6
# 91 2018-10-31     TMAX  GHCND:USW00014732  ,,W,2400    17.8
# 92 2018-10-31     TMIN  GHCND:USW00014732  ,,W,2400     7.2
#
# [93 rows x 5 columns]

# %%
df.date.describe()
# Out:
# C:\Users\KDS\AppData\Local\Temp\ipykernel_21308\1371252037.py:1: FutureWarning: The behavior of value_counts with object-dtype is deprecated. In a future version, this will *not* perform dtype inference on the resulting index. To retain the old behavior, use `result.index = result.index.infer_objects()`
#   df.date.describe()
# count                      93
# unique                     31
# top       2018-10-01 00:00:00
# freq                        3
# Name: date, dtype: object

# %%
pd.date_range(start="2018-10-25", periods=2, freq="D").tz_localize("EST")
# Out:
# DatetimeIndex(['2018-10-25 00:00:00-05:00', '2018-10-26 00:00:00-05:00'], dtype='datetime64[ns, EST]', freq=None)

# %%
eastern = pd.read_csv(
    "./Documents/datasets/nyc_temperatures.csv", index_col="date", parse_dates=True
).tz_localize("EST")

# %%
eastern.head()
# Out:
#                           datatype            station attributes  value
# date
# 2018-10-01 00:00:00-05:00     TAVG  GHCND:USW00014732      H,,S,   21.2
# 2018-10-01 00:00:00-05:00     TMAX  GHCND:USW00014732   ,,W,2400   25.6
# 2018-10-01 00:00:00-05:00     TMIN  GHCND:USW00014732   ,,W,2400   18.3
# 2018-10-02 00:00:00-05:00     TAVG  GHCND:USW00014732      H,,S,   22.7
# 2018-10-02 00:00:00-05:00     TMAX  GHCND:USW00014732   ,,W,2400   26.1

# %%
eastern.tz_convert("UTC").head()
# Out:
#                           datatype            station attributes  value
# date
# 2018-10-01 05:00:00+00:00     TAVG  GHCND:USW00014732      H,,S,   21.2
# 2018-10-01 05:00:00+00:00     TMAX  GHCND:USW00014732   ,,W,2400   25.6
# 2018-10-01 05:00:00+00:00     TMIN  GHCND:USW00014732   ,,W,2400   18.3
# 2018-10-02 05:00:00+00:00     TAVG  GHCND:USW00014732      H,,S,   22.7
# 2018-10-02 05:00:00+00:00     TMAX  GHCND:USW00014732   ,,W,2400   26.1

# %%
eastern.tz_localize(None).to_period("M").index
# Out:
# PeriodIndex(['2018-10', '2018-10', '2018-10', '2018-10', '2018-10', '2018-10',
#              '2018-10', '2018-10', '2018-10', '2018-10', '2018-10', '2018-10',
#              '2018-10', '2018-10', '2018-10', '2018-10', '2018-10', '2018-10',
#              '2018-10', '2018-10', '2018-10', '2018-10', '2018-10', '2018-10',
#              '2018-10', '2018-10', '2018-10', '2018-10', '2018-10', '2018-10',
#              '2018-10', '2018-10', '2018-10', '2018-10', '2018-10', '2018-10',
#              '2018-10', '2018-10', '2018-10', '2018-10', '2018-10', '2018-10',
#              '2018-10', '2018-10', '2018-10', '2018-10', '2018-10', '2018-10',
#              '2018-10', '2018-10', '2018-10', '2018-10', '2018-10', '2018-10',
#              '2018-10', '2018-10', '2018-10', '2018-10', '2018-10', '2018-10',
#              '2018-10', '2018-10', '2018-10', '2018-10', '2018-10', '2018-10',
#              '2018-10', '2018-10', '2018-10', '2018-10', '2018-10', '2018-10',
#              '2018-10', '2018-10', '2018-10', '2018-10', '2018-10', '2018-10',
#              '2018-10', '2018-10', '2018-10', '2018-10', '2018-10', '2018-10',
#              '2018-10', '2018-10', '2018-10', '2018-10', '2018-10', '2018-10',
#              '2018-10', '2018-10', '2018-10'],
#             dtype='period[M]', name='date')

# %%
eastern.tz_localize(None).to_period("M").to_timestamp().index
# Out:
# DatetimeIndex(['2018-10-01', '2018-10-01', '2018-10-01', '2018-10-01',
#                '2018-10-01', '2018-10-01', '2018-10-01', '2018-10-01',
#                '2018-10-01', '2018-10-01', '2018-10-01', '2018-10-01',
#                '2018-10-01', '2018-10-01', '2018-10-01', '2018-10-01',
#                '2018-10-01', '2018-10-01', '2018-10-01', '2018-10-01',
#                '2018-10-01', '2018-10-01', '2018-10-01', '2018-10-01',
#                '2018-10-01', '2018-10-01', '2018-10-01', '2018-10-01',
#                '2018-10-01', '2018-10-01', '2018-10-01', '2018-10-01',
#                '2018-10-01', '2018-10-01', '2018-10-01', '2018-10-01',
#                '2018-10-01', '2018-10-01', '2018-10-01', '2018-10-01',
#                '2018-10-01', '2018-10-01', '2018-10-01', '2018-10-01',
#                '2018-10-01', '2018-10-01', '2018-10-01', '2018-10-01',
#                '2018-10-01', '2018-10-01', '2018-10-01', '2018-10-01',
#                '2018-10-01', '2018-10-01', '2018-10-01', '2018-10-01',
#                '2018-10-01', '2018-10-01', '2018-10-01', '2018-10-01',
#                '2018-10-01', '2018-10-01', '2018-10-01', '2018-10-01',
#                '2018-10-01', '2018-10-01', '2018-10-01', '2018-10-01',
#                '2018-10-01', '2018-10-01', '2018-10-01', '2018-10-01',
#                '2018-10-01', '2018-10-01', '2018-10-01', '2018-10-01',
#                '2018-10-01', '2018-10-01', '2018-10-01', '2018-10-01',
#                '2018-10-01', '2018-10-01', '2018-10-01', '2018-10-01',
#                '2018-10-01', '2018-10-01', '2018-10-01', '2018-10-01',
#                '2018-10-01', '2018-10-01', '2018-10-01', '2018-10-01',
#                '2018-10-01'],
#               dtype='datetime64[ns]', name='date', freq=None)

# %%
df = pd.read_csv("./Documents/datasets/nyc_temperatures.csv").rename(
    columns={
        "value": "temp_C",
        "attributes": "flags"
    }
)

# %%
df
# Out:
#                    date datatype            station     flags  temp_C
# 0   2018-10-01T00:00:00     TAVG  GHCND:USW00014732     H,,S,    21.2
# 1   2018-10-01T00:00:00     TMAX  GHCND:USW00014732  ,,W,2400    25.6
# 2   2018-10-01T00:00:00     TMIN  GHCND:USW00014732  ,,W,2400    18.3
# 3   2018-10-02T00:00:00     TAVG  GHCND:USW00014732     H,,S,    22.7
# 4   2018-10-02T00:00:00     TMAX  GHCND:USW00014732  ,,W,2400    26.1
# ..                  ...      ...                ...       ...     ...
# 88  2018-10-30T00:00:00     TMAX  GHCND:USW00014732  ,,W,2400    13.9
# 89  2018-10-30T00:00:00     TMIN  GHCND:USW00014732  ,,W,2400     7.2
# 90  2018-10-31T00:00:00     TAVG  GHCND:USW00014732     H,,S,    12.6
# 91  2018-10-31T00:00:00     TMAX  GHCND:USW00014732  ,,W,2400    17.8
# 92  2018-10-31T00:00:00     TMIN  GHCND:USW00014732  ,,W,2400     7.2
#
# [93 rows x 5 columns]

# %%
new_df = df.assign(
    date=pd.to_datetime(df.date),
    temp_F = (df.temp_C * 9/5) + 32
)

# %%
new_df
# Out:
#          date datatype            station     flags  temp_C  temp_F
# 0  2018-10-01     TAVG  GHCND:USW00014732     H,,S,    21.2   70.16
# 1  2018-10-01     TMAX  GHCND:USW00014732  ,,W,2400    25.6   78.08
# 2  2018-10-01     TMIN  GHCND:USW00014732  ,,W,2400    18.3   64.94
# 3  2018-10-02     TAVG  GHCND:USW00014732     H,,S,    22.7   72.86
# 4  2018-10-02     TMAX  GHCND:USW00014732  ,,W,2400    26.1   78.98
# ..        ...      ...                ...       ...     ...     ...
# 88 2018-10-30     TMAX  GHCND:USW00014732  ,,W,2400    13.9   57.02
# 89 2018-10-30     TMIN  GHCND:USW00014732  ,,W,2400     7.2   44.96
# 90 2018-10-31     TAVG  GHCND:USW00014732     H,,S,    12.6   54.68
# 91 2018-10-31     TMAX  GHCND:USW00014732  ,,W,2400    17.8   64.04
# 92 2018-10-31     TMIN  GHCND:USW00014732  ,,W,2400     7.2   44.96
#
# [93 rows x 6 columns]

# %%
new_df.dtypes
# Out:
# date        datetime64[ns]
# datatype            object
# station             object
# flags               object
# temp_C             float64
# temp_F             float64
# dtype: object

# %%
new_df.head()
# Out:
#         date datatype            station     flags  temp_C  temp_F
# 0 2018-10-01     TAVG  GHCND:USW00014732     H,,S,    21.2   70.16
# 1 2018-10-01     TMAX  GHCND:USW00014732  ,,W,2400    25.6   78.08
# 2 2018-10-01     TMIN  GHCND:USW00014732  ,,W,2400    18.3   64.94
# 3 2018-10-02     TAVG  GHCND:USW00014732     H,,S,    22.7   72.86
# 4 2018-10-02     TMAX  GHCND:USW00014732  ,,W,2400    26.1   78.98

# %%
df = df.assign(
    date=lambda x: pd.to_datetime(x.date),
    temp_C_whole=lambda x: x.temp_C.astype("int"),
    temp_F=lambda x: (x.temp_C * 9 / 5) + 32,
    temp_F_whole=lambda x: x.temp_F.astype("int")
)

# %%
df.head()
# Out:
#         date datatype            station     flags  temp_C  temp_C_whole  \
# 0 2018-10-01     TAVG  GHCND:USW00014732     H,,S,    21.2            21
# 1 2018-10-01     TMAX  GHCND:USW00014732  ,,W,2400    25.6            25
# 2 2018-10-01     TMIN  GHCND:USW00014732  ,,W,2400    18.3            18
# 3 2018-10-02     TAVG  GHCND:USW00014732     H,,S,    22.7            22
# 4 2018-10-02     TMAX  GHCND:USW00014732  ,,W,2400    26.1            26
#
#    temp_F  temp_F_whole
# 0   70.16            70
# 1   78.08            78
# 2   64.94            64
# 3   72.86            72
# 4   78.98            78

# %%
df.date.dtypes
# Out:
# dtype('<M8[ns]')

# %%
df_with_categories = df.assign(
    station=df.station.astype("category"),
    datatype=df.datatype.astype("category")
)

# %%
df.dtypes
# Out:
# date            datetime64[ns]
# datatype                object
# station                 object
# flags                   object
# temp_C                 float64
# temp_C_whole             int32
# temp_F                 float64
# temp_F_whole             int32
# dtype: object

# %%
df_with_categories.dtypes
# Out:
# date            datetime64[ns]
# datatype              category
# station               category
# flags                   object
# temp_C                 float64
# temp_C_whole             int32
# temp_F                 float64
# temp_F_whole             int32
# dtype: object

# %%
pd.Categorical(
    ["med", "med", "low", "high"],
    categories=["low", "med", "high"],
    ordered=True
)
# Out:
# ['med', 'med', 'low', 'high']
# Categories (3, object): ['low' < 'med' < 'high']

# %% [markdown]
# ## Reordering, reindexing, and sorting

# %%
df[df.datatype == "TMAX"].sort_values(by="temp_C", ascending=False).head(10)
# Out:
#          date datatype            station     flags  temp_C  temp_C_whole  \
# 19 2018-10-07     TMAX  GHCND:USW00014732  ,,W,2400    27.8            27
# 28 2018-10-10     TMAX  GHCND:USW00014732  ,,W,2400    27.8            27
# 31 2018-10-11     TMAX  GHCND:USW00014732  ,,W,2400    26.7            26
# 10 2018-10-04     TMAX  GHCND:USW00014732  ,,W,2400    26.1            26
# 4  2018-10-02     TMAX  GHCND:USW00014732  ,,W,2400    26.1            26
# 1  2018-10-01     TMAX  GHCND:USW00014732  ,,W,2400    25.6            25
# 25 2018-10-09     TMAX  GHCND:USW00014732  ,,W,2400    25.6            25
# 7  2018-10-03     TMAX  GHCND:USW00014732  ,,W,2400    25.0            25
# 13 2018-10-05     TMAX  GHCND:USW00014732  ,,W,2400    22.8            22
# 22 2018-10-08     TMAX  GHCND:USW00014732  ,,W,2400    22.8            22
#
#     temp_F  temp_F_whole
# 19   82.04            82
# 28   82.04            82
# 31   80.06            80
# 10   78.98            78
# 4    78.98            78
# 1    78.08            78
# 25   78.08            78
# 7    77.00            77
# 13   73.04            73
# 22   73.04            73

# %%
df[df.datatype == "TMAX"].sort_values(by=["temp_C", "date"], ascending=[False, True]).head(10)
# Out:
#          date datatype            station     flags  temp_C  temp_C_whole  \
# 19 2018-10-07     TMAX  GHCND:USW00014732  ,,W,2400    27.8            27
# 28 2018-10-10     TMAX  GHCND:USW00014732  ,,W,2400    27.8            27
# 31 2018-10-11     TMAX  GHCND:USW00014732  ,,W,2400    26.7            26
# 4  2018-10-02     TMAX  GHCND:USW00014732  ,,W,2400    26.1            26
# 10 2018-10-04     TMAX  GHCND:USW00014732  ,,W,2400    26.1            26
# 1  2018-10-01     TMAX  GHCND:USW00014732  ,,W,2400    25.6            25
# 25 2018-10-09     TMAX  GHCND:USW00014732  ,,W,2400    25.6            25
# 7  2018-10-03     TMAX  GHCND:USW00014732  ,,W,2400    25.0            25
# 13 2018-10-05     TMAX  GHCND:USW00014732  ,,W,2400    22.8            22
# 22 2018-10-08     TMAX  GHCND:USW00014732  ,,W,2400    22.8            22
#
#     temp_F  temp_F_whole
# 19   82.04            82
# 28   82.04            82
# 31   80.06            80
# 4    78.98            78
# 10   78.98            78
# 1    78.08            78
# 25   78.08            78
# 7    77.00            77
# 13   73.04            73
# 22   73.04            73

# %%
df[df.datatype == "TMAX"].sort_values(by=["temp_C", "date"], ascending=[False, True], ignore_index=True).head(10)
# Out:
#         date datatype            station     flags  temp_C  temp_C_whole  \
# 0 2018-10-07     TMAX  GHCND:USW00014732  ,,W,2400    27.8            27
# 1 2018-10-10     TMAX  GHCND:USW00014732  ,,W,2400    27.8            27
# 2 2018-10-11     TMAX  GHCND:USW00014732  ,,W,2400    26.7            26
# 3 2018-10-02     TMAX  GHCND:USW00014732  ,,W,2400    26.1            26
# 4 2018-10-04     TMAX  GHCND:USW00014732  ,,W,2400    26.1            26
# 5 2018-10-01     TMAX  GHCND:USW00014732  ,,W,2400    25.6            25
# 6 2018-10-09     TMAX  GHCND:USW00014732  ,,W,2400    25.6            25
# 7 2018-10-03     TMAX  GHCND:USW00014732  ,,W,2400    25.0            25
# 8 2018-10-05     TMAX  GHCND:USW00014732  ,,W,2400    22.8            22
# 9 2018-10-08     TMAX  GHCND:USW00014732  ,,W,2400    22.8            22
#
#    temp_F  temp_F_whole
# 0   82.04            82
# 1   82.04            82
# 2   80.06            80
# 3   78.98            78
# 4   78.98            78
# 5   78.08            78
# 6   78.08            78
# 7   77.00            77
# 8   73.04            73
# 9   73.04            73

# %%
df[df.datatype == "TAVG"].nlargest(n=10, columns="temp_C")
# Out:
#          date datatype            station  flags  temp_C  temp_C_whole  \
# 27 2018-10-10     TAVG  GHCND:USW00014732  H,,S,    23.8            23
# 30 2018-10-11     TAVG  GHCND:USW00014732  H,,S,    23.4            23
# 18 2018-10-07     TAVG  GHCND:USW00014732  H,,S,    22.8            22
# 3  2018-10-02     TAVG  GHCND:USW00014732  H,,S,    22.7            22
# 6  2018-10-03     TAVG  GHCND:USW00014732  H,,S,    21.8            21
# 24 2018-10-09     TAVG  GHCND:USW00014732  H,,S,    21.8            21
# 9  2018-10-04     TAVG  GHCND:USW00014732  H,,S,    21.3            21
# 0  2018-10-01     TAVG  GHCND:USW00014732  H,,S,    21.2            21
# 21 2018-10-08     TAVG  GHCND:USW00014732  H,,S,    20.9            20
# 12 2018-10-05     TAVG  GHCND:USW00014732  H,,S,    20.3            20
#
#     temp_F  temp_F_whole
# 27   74.84            74
# 30   74.12            74
# 18   73.04            73
# 3    72.86            72
# 6    71.24            71
# 24   71.24            71
# 9    70.34            70
# 0    70.16            70
# 21   69.62            69
# 12   68.54            68

# %%
df.nsmallest(n=5, columns=["temp_C", "date"])
# Out:
#          date datatype            station     flags  temp_C  temp_C_whole  \
# 65 2018-10-22     TMIN  GHCND:USW00014732  ,,W,2400     5.6             5
# 77 2018-10-26     TMIN  GHCND:USW00014732  ,,W,2400     5.6             5
# 62 2018-10-21     TMIN  GHCND:USW00014732  ,,W,2400     6.1             6
# 74 2018-10-25     TMIN  GHCND:USW00014732  ,,W,2400     6.1             6
# 53 2018-10-18     TMIN  GHCND:USW00014732  ,,W,2400     6.7             6
#
#     temp_F  temp_F_whole
# 65   42.08            42
# 77   42.08            42
# 62   42.98            42
# 74   42.98            42
# 53   44.06            44

# %%
df.sample(5, random_state=0).index
# Out:
# Index([2, 30, 55, 16, 13], dtype='int64')

# %%
df.sample(5, random_state=0).sort_index().index
# Out:
# Index([2, 13, 16, 30, 55], dtype='int64')

# %%
df.sort_index(axis=1).head()
# Out:
#   datatype       date     flags            station  temp_C  temp_C_whole  \
# 0     TAVG 2018-10-01     H,,S,  GHCND:USW00014732    21.2            21
# 1     TMAX 2018-10-01  ,,W,2400  GHCND:USW00014732    25.6            25
# 2     TMIN 2018-10-01  ,,W,2400  GHCND:USW00014732    18.3            18
# 3     TAVG 2018-10-02     H,,S,  GHCND:USW00014732    22.7            22
# 4     TMAX 2018-10-02  ,,W,2400  GHCND:USW00014732    26.1            26
#
#    temp_F  temp_F_whole
# 0   70.16            70
# 1   78.08            78
# 2   64.94            64
# 3   72.86            72
# 4   78.98            78

# %%
df
# Out:
#          date datatype            station     flags  temp_C  temp_C_whole  \
# 0  2018-10-01     TAVG  GHCND:USW00014732     H,,S,    21.2            21
# 1  2018-10-01     TMAX  GHCND:USW00014732  ,,W,2400    25.6            25
# 2  2018-10-01     TMIN  GHCND:USW00014732  ,,W,2400    18.3            18
# 3  2018-10-02     TAVG  GHCND:USW00014732     H,,S,    22.7            22
# 4  2018-10-02     TMAX  GHCND:USW00014732  ,,W,2400    26.1            26
# ..        ...      ...                ...       ...     ...           ...
# 88 2018-10-30     TMAX  GHCND:USW00014732  ,,W,2400    13.9            13
# 89 2018-10-30     TMIN  GHCND:USW00014732  ,,W,2400     7.2             7
# 90 2018-10-31     TAVG  GHCND:USW00014732     H,,S,    12.6            12
# 91 2018-10-31     TMAX  GHCND:USW00014732  ,,W,2400    17.8            17
# 92 2018-10-31     TMIN  GHCND:USW00014732  ,,W,2400     7.2             7
#
#     temp_F  temp_F_whole
# 0    70.16            70
# 1    78.08            78
# 2    64.94            64
# 3    72.86            72
# 4    78.98            78
# ..     ...           ...
# 88   57.02            57
# 89   44.96            44
# 90   54.68            54
# 91   64.04            64
# 92   44.96            44
#
# [93 rows x 8 columns]

# %%
df.sort_index(axis=1).loc[:, "temp_C":"temp_F_whole"]
# Out:
#     temp_C  temp_C_whole  temp_F  temp_F_whole
# 0     21.2            21   70.16            70
# 1     25.6            25   78.08            78
# 2     18.3            18   64.94            64
# 3     22.7            22   72.86            72
# 4     26.1            26   78.98            78
# ..     ...           ...     ...           ...
# 88    13.9            13   57.02            57
# 89     7.2             7   44.96            44
# 90    12.6            12   54.68            54
# 91    17.8            17   64.04            64
# 92     7.2             7   44.96            44
#
# [93 rows x 4 columns]

# %%
df
# Out:
#          date datatype            station     flags  temp_C  temp_C_whole  \
# 0  2018-10-01     TAVG  GHCND:USW00014732     H,,S,    21.2            21
# 1  2018-10-01     TMAX  GHCND:USW00014732  ,,W,2400    25.6            25
# 2  2018-10-01     TMIN  GHCND:USW00014732  ,,W,2400    18.3            18
# 3  2018-10-02     TAVG  GHCND:USW00014732     H,,S,    22.7            22
# 4  2018-10-02     TMAX  GHCND:USW00014732  ,,W,2400    26.1            26
# ..        ...      ...                ...       ...     ...           ...
# 88 2018-10-30     TMAX  GHCND:USW00014732  ,,W,2400    13.9            13
# 89 2018-10-30     TMIN  GHCND:USW00014732  ,,W,2400     7.2             7
# 90 2018-10-31     TAVG  GHCND:USW00014732     H,,S,    12.6            12
# 91 2018-10-31     TMAX  GHCND:USW00014732  ,,W,2400    17.8            17
# 92 2018-10-31     TMIN  GHCND:USW00014732  ,,W,2400     7.2             7
#
#     temp_F  temp_F_whole
# 0    70.16            70
# 1    78.08            78
# 2    64.94            64
# 3    72.86            72
# 4    78.98            78
# ..     ...           ...
# 88   57.02            57
# 89   44.96            44
# 90   54.68            54
# 91   64.04            64
# 92   44.96            44
#
# [93 rows x 8 columns]

# %%
df.sort_values(by="temp_C")
# Out:
#          date datatype            station     flags  temp_C  temp_C_whole  \
# 77 2018-10-26     TMIN  GHCND:USW00014732  ,,W,2400     5.6             5
# 65 2018-10-22     TMIN  GHCND:USW00014732  ,,W,2400     5.6             5
# 62 2018-10-21     TMIN  GHCND:USW00014732  ,,W,2400     6.1             6
# 74 2018-10-25     TMIN  GHCND:USW00014732  ,,W,2400     6.1             6
# 53 2018-10-18     TMIN  GHCND:USW00014732  ,,W,2400     6.7             6
# ..        ...      ...                ...       ...     ...           ...
# 4  2018-10-02     TMAX  GHCND:USW00014732  ,,W,2400    26.1            26
# 10 2018-10-04     TMAX  GHCND:USW00014732  ,,W,2400    26.1            26
# 31 2018-10-11     TMAX  GHCND:USW00014732  ,,W,2400    26.7            26
# 19 2018-10-07     TMAX  GHCND:USW00014732  ,,W,2400    27.8            27
# 28 2018-10-10     TMAX  GHCND:USW00014732  ,,W,2400    27.8            27
#
#     temp_F  temp_F_whole
# 77   42.08            42
# 65   42.08            42
# 62   42.98            42
# 74   42.98            42
# 53   44.06            44
# ..     ...           ...
# 4    78.98            78
# 10   78.98            78
# 31   80.06            80
# 19   82.04            82
# 28   82.04            82
#
# [93 rows x 8 columns]

# %%
df.equals(df.sort_values(by="temp_C"))
# Out:
# False

# %%
df.equals(df.sort_values(by="temp_C").sort_index())
# Out:
# True

# %%
df.set_index("date", inplace=True)

# %%
df.head()
# Out:
#            datatype            station     flags  temp_C  temp_C_whole  \
# date
# 2018-10-01     TAVG  GHCND:USW00014732     H,,S,    21.2            21
# 2018-10-01     TMAX  GHCND:USW00014732  ,,W,2400    25.6            25
# 2018-10-01     TMIN  GHCND:USW00014732  ,,W,2400    18.3            18
# 2018-10-02     TAVG  GHCND:USW00014732     H,,S,    22.7            22
# 2018-10-02     TMAX  GHCND:USW00014732  ,,W,2400    26.1            26
#
#             temp_F  temp_F_whole
# date
# 2018-10-01   70.16            70
# 2018-10-01   78.08            78
# 2018-10-01   64.94            64
# 2018-10-02   72.86            72
# 2018-10-02   78.98            78

# %%
df["2018-10-11":"2018-10-12"]
# Out:
#            datatype            station     flags  temp_C  temp_C_whole  \
# date
# 2018-10-11     TAVG  GHCND:USW00014732     H,,S,    23.4            23
# 2018-10-11     TMAX  GHCND:USW00014732  ,,W,2400    26.7            26
# 2018-10-11     TMIN  GHCND:USW00014732  ,,W,2400    21.7            21
# 2018-10-12     TAVG  GHCND:USW00014732     H,,S,    18.3            18
# 2018-10-12     TMAX  GHCND:USW00014732  ,,W,2400    22.2            22
# 2018-10-12     TMIN  GHCND:USW00014732  ,,W,2400    12.2            12
#
#             temp_F  temp_F_whole
# date
# 2018-10-11   74.12            74
# 2018-10-11   80.06            80
# 2018-10-11   71.06            71
# 2018-10-12   64.94            64
# 2018-10-12   71.96            71
# 2018-10-12   53.96            53

# %%
df["2018-10-11":"2018-10-12"].reset_index()
# Out:
#         date datatype            station     flags  temp_C  temp_C_whole  \
# 0 2018-10-11     TAVG  GHCND:USW00014732     H,,S,    23.4            23
# 1 2018-10-11     TMAX  GHCND:USW00014732  ,,W,2400    26.7            26
# 2 2018-10-11     TMIN  GHCND:USW00014732  ,,W,2400    21.7            21
# 3 2018-10-12     TAVG  GHCND:USW00014732     H,,S,    18.3            18
# 4 2018-10-12     TMAX  GHCND:USW00014732  ,,W,2400    22.2            22
# 5 2018-10-12     TMIN  GHCND:USW00014732  ,,W,2400    12.2            12
#
#    temp_F  temp_F_whole
# 0   74.12            74
# 1   80.06            80
# 2   71.06            71
# 3   64.94            64
# 4   71.96            71
# 5   53.96            53

# %%
sp = pd.read_csv(
    "./Documents/datasets/sp500.csv", index_col="date", parse_dates=True
).drop(columns=["adj_close"])

# %%
sp
# Out:
#                    high          low         open        close      volume
# date
# 2017-01-03  2263.879883  2245.129883  2251.570068  2257.830078  3770530000
# 2017-01-04  2272.820068  2261.600098  2261.600098  2270.750000  3764890000
# 2017-01-05  2271.500000  2260.449951  2268.179932  2269.000000  3761820000
# 2017-01-06  2282.100098  2264.060059  2271.139893  2276.979980  3339890000
# 2017-01-09  2275.489990  2268.899902  2273.590088  2268.899902  3217610000
# ...                 ...          ...          ...          ...         ...
# 2018-12-24  2410.340088  2351.100098  2400.560059  2351.100098  2613930000
# 2018-12-26  2467.760010  2346.580078  2363.120117  2467.699951  4233990000
# 2018-12-27  2489.100098  2397.939941  2442.500000  2488.830078  4096610000
# 2018-12-28  2520.270020  2472.889893  2498.770020  2485.739990  3702620000
# 2018-12-31  2509.239990  2482.820068  2498.939941  2506.850098  3442870000
#
# [502 rows x 5 columns]

# %%
sp.head(10).assign(
    day_of_week=lambda x: x.index.day_name()
)
# Out:
#                    high          low         open        close      volume  \
# date
# 2017-01-03  2263.879883  2245.129883  2251.570068  2257.830078  3770530000
# 2017-01-04  2272.820068  2261.600098  2261.600098  2270.750000  3764890000
# 2017-01-05  2271.500000  2260.449951  2268.179932  2269.000000  3761820000
# 2017-01-06  2282.100098  2264.060059  2271.139893  2276.979980  3339890000
# 2017-01-09  2275.489990  2268.899902  2273.590088  2268.899902  3217610000
# 2017-01-10  2279.270020  2265.270020  2269.719971  2268.899902  3638790000
# 2017-01-11  2275.320068  2260.830078  2268.600098  2275.320068  3620410000
# 2017-01-12  2271.780029  2254.250000  2271.139893  2270.439941  3462130000
# 2017-01-13  2278.679932  2271.510010  2272.739990  2274.639893  3081270000
# 2017-01-17  2272.080078  2262.810059  2269.139893  2267.889893  3584990000
#
#            day_of_week
# date
# 2017-01-03     Tuesday
# 2017-01-04   Wednesday
# 2017-01-05    Thursday
# 2017-01-06      Friday
# 2017-01-09      Monday
# 2017-01-10     Tuesday
# 2017-01-11   Wednesday
# 2017-01-12    Thursday
# 2017-01-13      Friday
# 2017-01-17     Tuesday

# %%
bitcoin = pd.read_csv(
    "./Documents/datasets/bitcoin.csv", index_col="date", parse_dates=True
).drop(columns=["market_cap"])

# %%
bitcoin
# Out:
#                open     high      low    close      volume
# date
# 2017-01-01   963.66  1003.08   958.70   998.33   147775008
# 2017-01-02   998.62  1031.39   996.70  1021.75   222184992
# 2017-01-03  1021.60  1044.08  1021.60  1043.84   185168000
# 2017-01-04  1044.40  1159.42  1044.40  1154.73   344945984
# 2017-01-05  1156.73  1191.10   910.42  1013.38   510199008
# ...             ...      ...      ...      ...         ...
# 2018-12-27  3854.69  3874.42  3645.45  3654.83  5130222366
# 2018-12-28  3653.13  3956.14  3642.63  3923.92  5631554348
# 2018-12-29  3932.49  3963.76  3820.41  3820.41  4991655917
# 2018-12-30  3822.38  3901.91  3797.22  3865.95  4770578575
# 2018-12-31  3866.84  3868.74  3725.87  3742.70  4661840806
#
# [730 rows x 5 columns]

# %%
portfolio = pd.concat([sp, bitcoin], sort=False).groupby(level="date").sum()

# %%
portfolio.head(10).assign(
    day_of_week=lambda x: x.index.day_name()
)
# Out:
#                    high          low         open        close      volume  \
# date
# 2017-01-01  1003.080000   958.700000   963.660000   998.330000   147775008
# 2017-01-02  1031.390000   996.700000   998.620000  1021.750000   222184992
# 2017-01-03  3307.959883  3266.729883  3273.170068  3301.670078  3955698000
# 2017-01-04  3432.240068  3306.000098  3306.000098  3425.480000  4109835984
# 2017-01-05  3462.600000  3170.869951  3424.909932  3282.380000  4272019008
# 2017-01-06  3328.910098  3148.000059  3285.379893  3179.179980  3691766000
# 2017-01-07   908.590000   823.560000   903.490000   908.590000   279550016
# 2017-01-08   942.720000   887.250000   908.170000   911.200000   158715008
# 2017-01-09  3189.179990  3148.709902  3186.830088  3171.729902  3359486992
# 2017-01-10  3194.140020  3166.330020  3172.159971  3176.579902  3754598000
#
#            day_of_week
# date
# 2017-01-01      Sunday
# 2017-01-02      Monday
# 2017-01-03     Tuesday
# 2017-01-04   Wednesday
# 2017-01-05    Thursday
# 2017-01-06      Friday
# 2017-01-07    Saturday
# 2017-01-08      Sunday
# 2017-01-09      Monday
# 2017-01-10     Tuesday

# %%
import matplotlib.pyplot as plt
from matplotlib.ticker import StrMethodFormatter

# %%
ax = portfolio["2017-Q4":"2018-Q2"].plot(
    y="close", figsize=(15, 5), legend=False,
    title="Bitcoin + S&P 500 value without accouting for different indices"
)

# %%
ax = portfolio["2017-Q4":"2018-Q2"].plot(
    y="close", figsize=(15, 5), legend=False,
    title="Bitcoin + S&P 500 value without accouting for different indices"
)

ax.set_ylabel("price")
ax.yaxis.set_major_formatter(StrMethodFormatter("${x:,.0f}"))

for spine in ["top", "right"]:
    ax.spines[spine].set_visible(False)

plt.show()
